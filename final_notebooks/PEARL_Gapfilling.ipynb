# %% [markdown]
# # GAPFILLING PEARL

# %% [markdown]
# ## DATA

# %% [markdown]
# ### TIDE DATA

# %% [markdown]
# ### CHINE CREEK DATA

# %% [markdown]
# ## HOUR TIME SERIES

# %% [markdown]
# ## GAM MODEL FUNCTION

# %% [markdown]
# ## PLOTTING FUNCTION + PLOTSs
